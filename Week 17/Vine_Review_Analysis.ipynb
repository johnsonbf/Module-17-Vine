# %%
import pandas as pd
import os

# %%
vine_data_df = pd.read_csv('vine_table_data.csv')
vine_data_df.head()
len(vine_data_df.index)
# Out:
# 85981

# %%
filtered_df = vine_data_df[vine_data_df['total_votes'] >=20]
filtered_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 884    R2PT2X8FMYFCV3            5             39           41    N
# 917     RGCUQSH80SYY7            1             36           47    N
# 939    R3E6EI073KP0AL            2             21           36    N
# 947    R3MYTXW7B4Z6YW            4            687          711    N
# 1211   R2WMF1IWN5ZYO4            5             18           24    N
# ...               ...          ...            ...          ...  ...
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85979  R1O8C9XEYHQUIH            2             38           41    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase\
# 884                   Y\
# 917                   N\
# 939                   Y\
# 947                   Y\
# 1211                  Y\
# ...                  ...
# 85976                 N\
# 85977                 N\
# 85978                 N\
# 85979                 N\
# 85980                 N}
#
# [3414 rows x 6 columns]

# %%
votes_df = filtered_df[filtered_df['helpful_votes']/filtered_df['total_votes'] >=.5]
votes_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 884    R2PT2X8FMYFCV3            5             39           41    N
# 917     RGCUQSH80SYY7            1             36           47    N
# 939    R3E6EI073KP0AL            2             21           36    N
# 947    R3MYTXW7B4Z6YW            4            687          711    N
# 1211   R2WMF1IWN5ZYO4            5             18           24    N
# ...               ...          ...            ...          ...  ...
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85979  R1O8C9XEYHQUIH            2             38           41    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase\
# 884                   Y\
# 917                   N\
# 939                   Y\
# 947                   Y\
# 1211                  Y\
# ...                  ...
# 85976                 N\
# 85977                 N\
# 85978                 N\
# 85979                 N\
# 85980                 N}
#
# [3097 rows x 6 columns]

# %%
vine_program_yes = votes_df[votes_df['vine'] == 'Y']
vine_program_yes
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 32351  R3R2RHQWEKX5NL            5             81           89    Y
# 32362  R1RZ4JZO8DAP7H            3            200          227    Y
# 32557   RQ94HI0WM8KIG            5            174          188    Y
#
#       verified_purchase\
# 32351                 N\
# 32362                 N\
# 32557                 N\

# %%
vine_program_yes.groupby('star_rating').count()
# Out:
#              review_id  helpful_votes  total_votes  vine  verified_purchase\
# star_rating
# 3                    1              1            1     1                   1
# 5                    2              2            2     2                   2

# %%
len(vine_program_yes.index)
# Out:
# 3

# %%
vine_program_no = votes_df[votes_df['vine'] == 'N']
vine_program_no
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 884    R2PT2X8FMYFCV3            5             39           41    N
# 917     RGCUQSH80SYY7            1             36           47    N
# 939    R3E6EI073KP0AL            2             21           36    N
# 947    R3MYTXW7B4Z6YW            4            687          711    N
# 1211   R2WMF1IWN5ZYO4            5             18           24    N
# ...               ...          ...            ...          ...  ...
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85979  R1O8C9XEYHQUIH            2             38           41    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase\
# 884                   Y\
# 917                   N\
# 939                   Y\
# 947                   Y\
# 1211                  Y\
# ...                  ...
# 85976                 N\
# 85977                 N\
# 85978                 N\
# 85979                 N\
# 85980                 N}
#
# [3094 rows x 6 columns]

# %%
vine_program_no.groupby('star_rating').count()
# Out:
#              review_id  helpful_votes  total_votes  vine  verified_purchase\
# star_rating
# 1                  534            534          534   534                 534
# 2                  157            157          157   157                 157
# 3                  251            251          251   251                 251
# 4                  448            448          448   448                 448
# 5                 1704           1704         1704  1704                1704

# %%
len(vine_program_no.index)
# Out:
# 3094

# %%
total_reviews = vine_data_df.groupby('star_rating').count()
total_reviews
#total_reviews_filtered_no = vine_data_df[vine_data_df['vine'] == 'N'].count()
#total_reviews_filtered_yes = total_reviews[total_reviews['vine'] == 'Y']
#total_reviews_filtered_no
# Out:
#              review_id  helpful_votes  total_votes   vine  verified_purchase\
# star_rating
# 1                11036          11036        11036  11036               11036
# 2                 5341           5341         5341   5341                5341
# 3                 7050           7050         7050   7050                7050
# 4                13657          13657        13657  13657               13657
# 5                48897          48897        48897  48897               48897

# %%
total_reviews.dtypes
# Out:
# review_id             int64
# helpful_votes         int64
# total_votes           int64
# vine                  int64
# verified_purchase\    int64
# dtype: object

# %%
vine_reviews = vine_data_df.groupby('vine').count()
vine_reviews
# Out:
#       review_id  star_rating  helpful_votes  total_votes  verified_purchase\
# vine
# N         85949        85949          85949        85949               85949
# Y            32           32             32           32                  32

# %%
percentage_N = (20612/37840)*100
percentage_N
# Out:
# 54.471458773784356

# %%
percentage_Y = (65/170)*100
percentage_Y
# Out:
# 38.23529411764706
